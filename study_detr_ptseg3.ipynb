# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
folder_path = "/content/drive/MyDrive/Colab Notebooks/study/detr_colab"
import sys
sys.path.insert(0, folder_path)

# %%
from hubconf import detr_resnet50_panoptic
import torch

# %%
from PIL import Image
import requests
import io
import math
import matplotlib.pyplot as plt
import torchvision.transforms as T

# %%
model = detr_resnet50_panoptic(pretrained=False).eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 160MB/s]

# %%
x = [torch.rand(3, 800, 1200)]
pred = model(x)
# Out:
# DETRsegm forward
# forward(self, samples: NestedTensor)
# c2 torch.Size([1, 256, 200, 300])
# c3 torch.Size([1, 512, 100, 150])
# c4 torch.Size([1, 1024, 50, 75])
# c5 torch.Size([1, 2048, 25, 38])
# pos[0~3]
# torch.Size([1, 256, 200, 300])
# torch.Size([1, 256, 100, 150])
# torch.Size([1, 256, 50, 75])
# torch.Size([1, 256, 25, 38])
# src, mask = features[-1].decompose()
# src torch.Size([1, 2048, 25, 38])
# mask torch.Size([1, 25, 38])
# src_proj = self.detr.input_proj(src)
# src torch.Size([1, 2048, 25, 38])
# src_proj torch.Size([1, 256, 25, 38])
# hs, memory = self.detr.transformer(src_proj, mask, self.detr.query_embed.weight, pos[-1])
# Transformer forward
# forward(self, src, mask, query_embed, pos_embed)
# src torch.Size([1, 256, 25, 38])
# mask torch.Size([1, 25, 38])
# query_embed torch.Size([100, 256])
# pos_embed torch.Size([1, 256, 25, 38])
# memory = self.encoder(src, src_key_padding_mask=mask, pos=pos_embed)
# memory = torch.Size([950, 1, 256])
# hs = self.decoder(tgt, memory, memory_key_padding_mask=mask,pos=pos_embed, query_pos=query_embed)
# hs = torch.Size([6, 100, 1, 256])
# Transformer return
# self.detr.query_embed.weight self.query_embed = nn.Embedding(num_queries, hidden_dim)
# pos[-1] torch.Size([1, 256, 25, 38])
# hs torch.Size([6, 1, 100, 256])
# memory torch.Size([1, 256, 25, 38])
# bbox_mask = self.bbox_attention(hs[-1], memory, mask=mask)
# forward(self, q, k, mask: Optional[Tensor] = None)
# q = self.q_linear(q)
# torch.Size([1, 100, 256])
# k = F.conv2d(k, self.k_linear.weight.unsqueeze(-1).unsqueeze(-1), self.k_linear.bias)
# torch.Size([1, 256, 25, 38])
# qh = q.view(q.shape[0], q.shape[1], self.num_heads, self.hidden_dim // self.num_heads)
# torch.Size([1, 100, 8, 32])
# kh = k.view(k.shape[0], self.num_heads, self.hidden_dim // self.num_heads, k.shape[-2], k.shape[-1])
# torch.Size([1, 8, 32, 25, 38])
# weights = torch.einsum("bqnc,bnchw->bqnhw", qh * self.normalize_fact, kh)
# torch.Size([1, 100, 8, 25, 38])
# weights = F.softmax(weights.flatten(2), dim=-1).view(weights.size())
# return weights torch.Size([1, 100, 8, 25, 38])
# bbox_mask = self.bbox_attention(hs[-1], memory, mask=mask)
# bbox_mask torch.Size([1, 100, 8, 25, 38])
# seg_masks = self.mask_head(src_proj, bbox_mask, [features[2].tensors, features[1].tensors, features[0].tensors])
# inter_dims [264, 128, 64, 32, 16, 4]
# x torch.Size([1, 256, 25, 38])
# bbox_mask torch.Size([1, 100, 8, 25, 38])
# _expand(x, bbox_mask.shape[1]) torch.Size([100, 256, 25, 38])
# bbox_mask.flatten(0, 1) torch.Size([100, 8, 25, 38])
# x = torch.cat([_expand(x, bbox_mask.shape[1]), bbox_mask.flatten(0, 1)], 1)
# res5[100, 256, 25, 38] + [100, 8, 25, 38]
# x torch.Size([100, 264, 25, 38])
# x torch.Size([100, 128, 25, 38])
# fpns[0] torch.Size([1, 1024, 50, 75])
# cur_fpn[0] torch.Size([1, 128, 50, 75])
# cur_fpn[0] expanded torch.Size([100, 128, 50, 75])
# x = cur_fpn[0] + F.interpolate(x, size=cur_fpn.shape[-2:], mode="nearest")
# x torch.Size([100, 128, 50, 75])
# x torch.Size([100, 64, 50, 75])
# fpns[1] torch.Size([1, 512, 100, 150])
# cur_fpn[1] torch.Size([1, 64, 100, 150])
# cur_fpn[1] expanded torch.Size([100, 64, 100, 150])
# x = cur_fpn[1] + F.interpolate(x, size=cur_fpn.shape[-2:], mode="nearest")
# x torch.Size([100, 64, 100, 150])
# x torch.Size([100, 32, 100, 150])
# fpns[2] torch.Size([1, 256, 200, 300])
# cur_fpn[2] torch.Size([1, 32, 200, 300])
# cur_fpn[2] expanded torch.Size([100, 32, 200, 300])
# x = cur_fpn[2] + F.interpolate(x, size=cur_fpn.shape[-2:], mode="nearest")
# x torch.Size([100, 32, 200, 300])
# x torch.Size([100, 16, 200, 300])
# return x torch.Size([100, 1, 200, 300])
# seg_masks = self.mask_head(src_proj, bbox_mask, [features[2].tensors, features[1].tensors, features[0].tensors])
# src_proj torch.Size([1, 256, 25, 38])
# bbox_mask torch.Size([1, 100, 8, 25, 38])
# features[2].tensors torch.Size([1, 1024, 50, 75])
# features[1].tensors torch.Size([1, 512, 100, 150])
# features[0].tensors torch.Size([1, 256, 200, 300])
# seg_masks torch.Size([100, 1, 200, 300])
# outputs_seg_masks = seg_masks.view(bs, self.detr.num_queries, seg_masks.shape[-2], seg_masks.shape[-1])
# outputs_seg_masks torch.Size([1, 100, 200, 300])
